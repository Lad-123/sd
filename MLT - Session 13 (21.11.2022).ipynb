# %% [markdown]
# ## Dealing with Imbalanced Dataset

# %% [markdown]
# **We are going to study about imbalanced data by introducing the concept Upsampling and Downsampling.**
# **We will look into K-Nearest Neighbour, using a hyper parameterusing GridSearch CV and identify the best model.**

# %% [markdown]
# ### Accessing the dataset

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
bank = pd.read_csv('bank.csv')
bank
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 0        unknown    5   may       261         1     -1         0  unknown   no
# 1        unknown    5   may       151         1     -1         0  unknown   no
# 2        unknown    5   may        76         1     -1         0  unknown   no
# 3        unknown    5   may        92         1     -1         0  unknown   no
# 4        unknown    5   may       198         1     -1         0  unknown   no
# ...          ...  ...   ...       ...       ...    ...       ...      ...  ...
# 45206   cellular   17   nov       977         3     -1         0  unknown  yes
# 45207   cellular   17   nov       456         2     -1         0  unknown  yes
# 45208   cellular   17   nov      1127         5    184         3  success  yes
# 45209  telephone   17   nov       508         4     -1         0  unknown   no
# 45210   cellular   17   nov       361         2    188        11    other   no
#
# [45211 rows x 17 columns]

# %%
bank['y'].value_counts()
# Out:
# no     39922
# yes     5289
# Name: y, dtype: int64

# %%
5289/(5289+39922)
# Out:
# 0.11698480458295547

# %% [markdown]
# **Yes class has around 11.69% and No class has 88.31% of values**

# %% [markdown]
# **Imbalance Dataset is the one where the spread of the dataset is skewed to a large extent.**

# %% [markdown]
# ### Resolving the Imbalance

# %%
# Splitting the data into 2 according to the class

bank_yes = bank[bank['y'] == 'yes']
bank_yes.shape
# Out:
# (5289, 17)

# %%
bank_no = bank[bank['y'] == 'no']
bank_no.shape
# Out:
# (39922, 17)

# %% [markdown]
# ### Upsampling

# %% [markdown]
# **Upsampling is applied on the minority class inorder to increase the datapoints (manipulation). In this case we do it for the class "Yes".**

# %%
from sklearn.utils import resample

bank_yes_up = resample(bank_yes, replace = True, random_state = 100, n_samples = 15000)
bank_yes_up.shape
# Out:
# (15000, 17)

# %%
bank_yes_up
# Out:
#        age            job  marital  education default  balance housing loan  \
# 42571   38         admin.  married  secondary      no    11303      no   no
# 3190    41    blue-collar  married  secondary      no     1384     yes   no
# 10049   42   entrepreneur  married   tertiary      no     5345      no   no
# 31962   31    blue-collar  married  secondary      no     1406     yes  yes
# 43024   51     management  married   tertiary      no      346      no   no
# ...    ...            ...      ...        ...     ...      ...     ...  ...
# 38934   24       services   single  secondary      no      414     yes   no
# 42798   62   entrepreneur  married  secondary      no     3904      no   no
# 31333   58  self-employed  married   tertiary      no     5810      no   no
# 42557   33     management  married   tertiary      no     1808      no   no
# 35533   42     unemployed  married  secondary      no      356     yes   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 42571   cellular   28   dec       473         2    216         2  failure  yes
# 3190     unknown   15   may      1162         4     -1         0  unknown  yes
# 10049    unknown   11   jun       878         3     -1         0  unknown  yes
# 31962   cellular   13   apr      1091         2     -1         0  unknown  yes
# 43024   cellular   12   feb       122         1     92         5  success  yes
# ...          ...  ...   ...       ...       ...    ...       ...      ...  ...
# 38934   cellular   18   may       493         1    370         1    other  yes
# 42798  telephone   29   jan       403         2     -1         0  unknown  yes
# 31333   cellular   12   mar       139         1     -1         0  unknown  yes
# 42557   cellular   28   dec       250         3     -1         0  unknown  yes
# 35533   cellular    7   may       787         3    356         2  failure  yes
#
# [15000 rows x 17 columns]

# %% [markdown]
# ### Downsampling

# %% [markdown]
# **Downsampling is applied on the majority class inorder to decrease the datapoints (manipulation). In this case we do it for the class "No".**

# %%
bank_no_down = resample (bank_no, replace = False, random_state = 100, n_samples = 25000)
bank_no_down.shape
# Out:
# (25000, 17)

# %%
bank_no_down
# Out:
#        age          job   marital  education default  balance housing loan  \
# 9789    39  blue-collar   married   tertiary      no    10483      no   no
# 44899   77      retired   married   tertiary      no        0      no   no
# 2331    28  blue-collar   married  secondary      no      -95     yes   no
# 15271   41   management    single   tertiary      no        0     yes   no
# 10642   38     services  divorced  secondary      no      439      no   no
# ...    ...          ...       ...        ...     ...      ...     ...  ...
# 27927   43      unknown    single    unknown      no      181      no   no
# 18014   40   management  divorced   tertiary      no       69     yes   no
# 35076   40   management   married   tertiary      no      429     yes   no
# 11238   44  blue-collar    single    unknown      no     4330      no   no
# 4591    39       admin.   married  secondary      no     2019     yes   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome   y
# 9789     unknown    9   jun       218         1     -1         0  unknown  no
# 44899   cellular   27   sep       990         4     -1         0  unknown  no
# 2331     unknown   13   may       200         1     -1         0  unknown  no
# 15271   cellular   17   jul       509         7     -1         0  unknown  no
# 10642    unknown   16   jun        50         1     -1         0  unknown  no
# ...          ...  ...   ...       ...       ...    ...       ...      ...  ..
# 27927  telephone   28   jan        41         1     -1         0  unknown  no
# 18014   cellular   30   jul       149         2     -1         0  unknown  no
# 35076   cellular    6   may       222         2    363         4  failure  no
# 11238    unknown   18   jun        16         9     -1         0  unknown  no
# 4591     unknown   20   may       166         1     -1         0  unknown  no
#
# [25000 rows x 17 columns]

# %% [markdown]
# ### Creating a datset by combining

# %%
bank_new = pd.concat([bank_yes_up, bank_no_down])
bank_new.shape
# Out:
# (40000, 17)

# %%
bank_new.head(25)
# Out:
#        age           job   marital  education default  balance housing loan  \
# 42571   38        admin.   married  secondary      no    11303      no   no
# 3190    41   blue-collar   married  secondary      no     1384     yes   no
# 10049   42  entrepreneur   married   tertiary      no     5345      no   no
# 31962   31   blue-collar   married  secondary      no     1406     yes  yes
# 43024   51    management   married   tertiary      no      346      no   no
# 18015   55    management   married   tertiary      no     -375      no   no
# 44802   31    management    single   tertiary      no     3340      no   no
# 39724   43        admin.   married  secondary      no      132      no   no
# 43431   78       retired  divorced    primary      no     1389      no   no
# 31180   25    technician    single  secondary      no     1231     yes   no
# 41153   67       retired  divorced   tertiary      no      443      no   no
# 32027   36    technician   married  secondary      no    15485      no   no
# 26961   47    technician   married  secondary      no        0      no   no
# 40152   30    technician    single   tertiary      no        0     yes   no
# 30176   69    management   married   tertiary      no      840      no   no
# 36173   40      services   married  secondary      no     -192     yes   no
# 32028   33    management   married   tertiary      no        0     yes   no
# 36692   51   blue-collar   married  secondary      no      518     yes   no
# 44547   44    management   married   tertiary      no     1791      no   no
# 40862   32    technician   married  secondary      no      484     yes   no
# 44041   48        admin.    single  secondary      no     1544     yes   no
# 21224   47    management   married   tertiary      no      682      no   no
# 38732   32   blue-collar    single  secondary      no      217     yes   no
# 42785   54        admin.   married  secondary      no        0      no   no
# 39972   34    technician   married   tertiary      no      127      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 42571   cellular   28   dec       473         2    216         2  failure  yes
# 3190     unknown   15   may      1162         4     -1         0  unknown  yes
# 10049    unknown   11   jun       878         3     -1         0  unknown  yes
# 31962   cellular   13   apr      1091         2     -1         0  unknown  yes
# 43024   cellular   12   feb       122         1     92         5  success  yes
# 18015   cellular   30   jul       814         2     -1         0  unknown  yes
# 44802   cellular   15   sep       213         2    469         3  success  yes
# 39724   cellular   27   may       187         2     71         1  success  yes
# 43431   cellular    8   apr       335         1     -1         0  unknown  yes
# 31180   cellular   27   feb       412         5     -1         0  unknown  yes
# 41153   cellular   18   aug       441         1     -1         0  unknown  yes
# 32027   cellular   14   apr       461         1     -1         0  unknown  yes
# 26961   cellular   21   nov       591         1     10         1  failure  yes
# 40152   cellular    5   jun       159         2     -1         0  unknown  yes
# 30176  telephone    5   feb       128         3     -1         0  unknown  yes
# 36173   cellular   11   may       666         1     -1         0  unknown  yes
# 32028   cellular   14   apr       535         3    328         1  failure  yes
# 36692   cellular   12   may       918         1     -1         0  unknown  yes
# 44547  telephone   12   aug       201         1    182         2  success  yes
# 40862   cellular   12   aug       668         2    463         1  success  yes
# 44041  telephone   30   jun       263         1    450         2  failure  yes
# 21224   cellular   18   aug       638         6     -1         0  unknown  yes
# 38732   cellular   15   may       692         3     -1         0  unknown  yes
# 42785   cellular   28   jan       161         1     98         2  failure  yes
# 39972   cellular    3   jun       117         1     -1         0  unknown  yes

# %%
bank_new.tail(25)
# Out:
#        age            job   marital  education default  balance housing loan  \
# 8935    39    blue-collar   married    primary      no        0     yes   no
# 36257   40       services   married  secondary      no       51     yes   no
# 16162   32     management   married   tertiary      no      663      no  yes
# 37035   36     technician   married   tertiary      no      421     yes   no
# 13823   33     technician   married   tertiary      no     1746     yes   no
# 8260    54  self-employed   married    primary      no      277     yes   no
# 28590   28     technician   married   tertiary      no      203      no  yes
# 12183   40    blue-collar   married  secondary      no       95      no  yes
# 17209   37     management    single    unknown      no      242      no  yes
# 39681   25     management    single   tertiary      no      430      no  yes
# 27824   47    blue-collar   married    primary      no     1452     yes  yes
# 30958   46       services   married  secondary      no      692     yes   no
# 4985    31         admin.    single   tertiary      no     1583     yes   no
# 24394   46     management   married  secondary      no     1306     yes   no
# 30421   32       services   married  secondary      no      182      no   no
# 10069   53        retired    single  secondary      no     1846      no   no
# 4289    34         admin.   married  secondary      no      645     yes   no
# 39891   36    blue-collar   married  secondary      no       79     yes  yes
# 13713   40    blue-collar   married    primary      no      137      no  yes
# 24560   41     unemployed   married    primary      no      557     yes   no
# 27927   43        unknown    single    unknown      no      181      no   no
# 18014   40     management  divorced   tertiary      no       69     yes   no
# 35076   40     management   married   tertiary      no      429     yes   no
# 11238   44    blue-collar    single    unknown      no     4330      no   no
# 4591    39         admin.   married  secondary      no     2019     yes   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome   y
# 8935     unknown    4   jun       112         4     -1         0  unknown  no
# 36257   cellular   11   may        50         1     -1         0  unknown  no
# 16162   cellular   22   jul        62         3     -1         0  unknown  no
# 37035   cellular   13   may       793         5     -1         0  unknown  no
# 13823   cellular   10   jul       184         1     -1         0  unknown  no
# 8260     unknown    2   jun       360         3     -1         0  unknown  no
# 28590   cellular   29   jan       188         3     -1         0  unknown  no
# 12183    unknown   20   jun        61         4     -1         0  unknown  no
# 17209   cellular   28   jul       124         3     -1         0  unknown  no
# 39681   cellular   27   may       145         2     -1         0  unknown  no
# 27824   cellular   28   jan       181         1    177         2  failure  no
# 30958   cellular    9   feb       388         3    257         2  failure  no
# 4985     unknown   21   may       207         1     -1         0  unknown  no
# 24394  telephone   17   nov       155         1     -1         0  unknown  no
# 30421   cellular    5   feb       277         1    169         2  failure  no
# 10069    unknown   11   jun        95         1     -1         0  unknown  no
# 4289     unknown   19   may       420         1     -1         0  unknown  no
# 39891   cellular    2   jun        74         2     -1         0  unknown  no
# 13713   cellular   10   jul       214         1     -1         0  unknown  no
# 24560   cellular   17   nov       158         1    173         1  failure  no
# 27927  telephone   28   jan        41         1     -1         0  unknown  no
# 18014   cellular   30   jul       149         2     -1         0  unknown  no
# 35076   cellular    6   may       222         2    363         4  failure  no
# 11238    unknown   18   jun        16         9     -1         0  unknown  no
# 4591     unknown   20   may       166         1     -1         0  unknown  no

# %% [markdown]
# ### Shuffling the dataset

# %%
from sklearn.utils import shuffle

bank_new = shuffle(bank_new)
bank_new.shape
# Out:
# (40000, 17)

# %%
bank_new.head(25)
# Out:
#        age           job   marital  education default  balance housing loan  \
# 36373   33      services    single  secondary      no     -530     yes  yes
# 16791   25  entrepreneur   married   tertiary      no       30     yes   no
# 8084    35      services   married  secondary      no      152     yes   no
# 44095   71       retired  divorced    unknown      no      392      no   no
# 44556   35    management   married   tertiary      no     2717      no   no
# 12320   27   blue-collar   married   tertiary      no      335     yes   no
# 36526   41   blue-collar   married  secondary      no      849     yes  yes
# 37887   37      services   married  secondary      no     6089     yes   no
# 13400   36   blue-collar   married  secondary      no       56     yes   no
# 787     46    management   married   tertiary      no        0      no   no
# 16569   60    technician    single  secondary      no       12      no   no
# 28061   42   blue-collar    single  secondary      no      583      no   no
# 25714   54      services   married    unknown      no      386      no  yes
# 25174   38  entrepreneur   married   tertiary      no        0     yes   no
# 16192   27   blue-collar   married    primary      no      300      no  yes
# 12714   43    management  divorced  secondary      no        0      no   no
# 43041   58        admin.   married  secondary      no      169      no   no
# 44644   18       student    single    unknown      no      438      no   no
# 10858   47    technician  divorced  secondary      no      431      no  yes
# 31764   36   blue-collar    single  secondary      no     1822     yes   no
# 43456   25    unemployed    single    primary      no      129      no   no
# 43373   31    management    single   tertiary      no     4319     yes   no
# 6269    27   blue-collar    single  secondary     yes       87     yes   no
# 41500   19       student    single  secondary      no       88      no   no
# 44070   31       student    single  secondary      no     3511      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 36373  telephone   11   may       168         5     -1         0  unknown   no
# 16791   cellular   24   jul       254         2     -1         0  unknown   no
# 8084     unknown    2   jun       563         1     -1         0  unknown  yes
# 44095  telephone    7   jul       276         2     -1         0  unknown  yes
# 44556   cellular   13   aug       394         6     -1         0  unknown  yes
# 12320    unknown   26   jun       519         3     -1         0  unknown  yes
# 36526   cellular   12   may       100         4     -1         0  unknown   no
# 37887   cellular   14   may       616         2     -1         0  unknown  yes
# 13400   cellular    9   jul       183         1     -1         0  unknown   no
# 787      unknown    7   may        70         2     -1         0  unknown   no
# 16569   cellular   24   jul       205         1     -1         0  unknown   no
# 28061   cellular   28   jan       567         3     -1         0  unknown   no
# 25714   cellular   19   nov        74         1    152         1  success   no
# 25174   cellular   18   nov       185         3     -1         0  unknown   no
# 16192   cellular   22   jul       209         2     -1         0  unknown   no
# 12714   cellular    7   jul        75         3     -1         0  unknown   no
# 43041   cellular   15   feb       216         1     91         4  success  yes
# 44644   cellular    1   sep       425         1     -1         0  unknown   no
# 10858    unknown   17   jun       388         9     -1         0  unknown   no
# 31764   cellular    8   apr       952         1    323         1    other  yes
# 43456   cellular   12   apr       176         3     -1         0  unknown  yes
# 43373   cellular   29   mar       515         2    334         5  failure   no
# 6269     unknown   27   may        43         1     -1         0  unknown   no
# 41500   cellular    8   sep       191         1     -1         0  unknown   no
# 44070   cellular    2   jul       667         1     -1         0  unknown  yes

# %% [markdown]
# ### Splitting into target and features

# %%
y_tar = bank_new['y']
y_tar.shape
# Out:
# (40000,)

# %%
X = bank_new.drop(['y'], axis = 1)
X.shape
# Out:
# (40000, 16)

# %%
X
# Out:
#        age           job   marital  education default  balance housing loan  \
# 36373   33      services    single  secondary      no     -530     yes  yes
# 16791   25  entrepreneur   married   tertiary      no       30     yes   no
# 8084    35      services   married  secondary      no      152     yes   no
# 44095   71       retired  divorced    unknown      no      392      no   no
# 44556   35    management   married   tertiary      no     2717      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 26656   52     housemaid   married  secondary      no     3923     yes   no
# 44162   31    technician   married   tertiary      no     2166      no   no
# 37472   42    management   married   tertiary      no     1162     yes   no
# 18509   54        admin.   married  secondary      no      812     yes  yes
# 42635   87       retired   married    primary      no     2190      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome
# 36373  telephone   11   may       168         5     -1         0  unknown
# 16791   cellular   24   jul       254         2     -1         0  unknown
# 8084     unknown    2   jun       563         1     -1         0  unknown
# 44095  telephone    7   jul       276         2     -1         0  unknown
# 44556   cellular   13   aug       394         6     -1         0  unknown
# ...          ...  ...   ...       ...       ...    ...       ...      ...
# 26656   cellular   20   nov        20         8    190         3  success
# 44162   cellular   13   jul       577         6    182         2  success
# 37472   cellular   13   may       406         5    364         1    other
# 18509   cellular   31   jul        83         6     -1         0  unknown
# 42635  telephone   12   jan       512         2     -1         0  unknown
#
# [40000 rows x 16 columns]

# %%
# Converting the categorical features to numeric

X_new = pd.get_dummies(X)
X_new.shape
# Out:
# (40000, 51)

# %%
X_new
# Out:
#        age  balance  day  duration  campaign  pdays  previous  job_admin.  \
# 36373   33     -530   11       168         5     -1         0           0
# 16791   25       30   24       254         2     -1         0           0
# 8084    35      152    2       563         1     -1         0           0
# 44095   71      392    7       276         2     -1         0           0
# 44556   35     2717   13       394         6     -1         0           0
# ...    ...      ...  ...       ...       ...    ...       ...         ...
# 26656   52     3923   20        20         8    190         3           0
# 44162   31     2166   13       577         6    182         2           0
# 37472   42     1162   13       406         5    364         1           0
# 18509   54      812   31        83         6     -1         0           1
# 42635   87     2190   12       512         2     -1         0           0
#
#        job_blue-collar  job_entrepreneur  ...  month_jun  month_mar  \
# 36373                0                 0  ...          0          0
# 16791                0                 1  ...          0          0
# 8084                 0                 0  ...          1          0
# 44095                0                 0  ...          0          0
# 44556                0                 0  ...          0          0
# ...                ...               ...  ...        ...        ...
# 26656                0                 0  ...          0          0
# 44162                0                 0  ...          0          0
# 37472                0                 0  ...          0          0
# 18509                0                 0  ...          0          0
# 42635                0                 0  ...          0          0
#
#        month_may  month_nov  month_oct  month_sep  poutcome_failure  \
# 36373          1          0          0          0                 0
# 16791          0          0          0          0                 0
# 8084           0          0          0          0                 0
# 44095          0          0          0          0                 0
# 44556          0          0          0          0                 0
# ...          ...        ...        ...        ...               ...
# 26656          0          1          0          0                 0
# 44162          0          0          0          0                 0
# 37472          1          0          0          0                 0
# 18509          0          0          0          0                 0
# 42635          0          0          0          0                 0
#
#        poutcome_other  poutcome_success  poutcome_unknown
# 36373               0                 0                 1
# 16791               0                 0                 1
# 8084                0                 0                 1
# 44095               0                 0                 1
# 44556               0                 0                 1
# ...               ...               ...               ...
# 26656               0                 1                 0
# 44162               0                 1                 0
# 37472               1                 0                 0
# 18509               0                 0                 1
# 42635               0                 0                 1
#
# [40000 rows x 51 columns]

# %% [markdown]
# ### Standardization of features

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_sc = sc.fit_transform(X_new)
X_sc
# Out:
# array([[-0.70650057, -0.60798423, -0.55417447, ..., -0.21921049,
#         -0.28888227,  0.55166443],
#        [-1.40079886, -0.4412374 ,  0.99410664, ..., -0.21921049,
#         -0.28888227,  0.55166443],
#        [-0.532926  , -0.4049104 , -1.6260614 , ..., -0.21921049,
#         -0.28888227,  0.55166443],
#        ...,
#        [ 0.07458499, -0.10417057, -0.31597738, ...,  4.56182538,
#         -0.28888227, -1.81269616],
#        [ 1.11603242, -0.20838734,  1.82779647, ..., -0.21921049,
#         -0.28888227,  0.55166443],
#        [ 3.98001283,  0.20192899, -0.43507593, ..., -0.21921049,
#         -0.28888227,  0.55166443]])

# %% [markdown]
# ### Splitting the data into train and test

# %%
from sklearn.model_selection import train_test_split

X_sc_train, X_sc_test, y_tar_train, y_tar_test = train_test_split(X_sc, y_tar, test_size = 0.2, random_state = 100)

X_sc_train.shape, X_sc_test.shape, y_tar_train.shape, y_tar_test.shape
# Out:
# ((32000, 51), (8000, 51), (32000,), (8000,))

# %% [markdown]
# ### Model Building - K Nearest Neighbor Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()
knn.fit(X_sc_train, y_tar_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# ### Model performance

# %%
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score

cm = confusion_matrix(y_tar_test, knn.predict(X_sc_test))
report = classification_report(y_tar_test, knn.predict(X_sc_test))

print ("The Confusion matrix is: \n", cm)
print ("\n")
print ("The report is:\n", report)
# Out:
# The Confusion matrix is:
#  [[4285  698]
#  [ 527 2490]]
#
#
# The report is:
#                precision    recall  f1-score   support
#
#           no       0.89      0.86      0.87      4983
#          yes       0.78      0.83      0.80      3017
#
#     accuracy                           0.85      8000
#    macro avg       0.84      0.84      0.84      8000
# weighted avg       0.85      0.85      0.85      8000

# %% [markdown]
# ### Hyper-paramter turing using GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

knn_gs = GridSearchCV(knn, {'n_neighbors': range(3, 8)}) # The parameters are estimator and param_grid. Estimator is the model.
knn_gs.fit(X_sc_train, y_tar_train)
# Out:
# GridSearchCV(estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': range(3, 8)})

# %%
knn_gs.best_params_
# Out:
# {'n_neighbors': 3}

# %% [markdown]
# ### Creating the best KNN Model

# %%
knn_best = KNeighborsClassifier(n_neighbors = 3)
knn_best.fit(X_sc_train, y_tar_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
report = classification_report(y_tar_test, knn_best.predict(X_sc_test))
cm = confusion_matrix (y_tar_test, knn_best.predict(X_sc_test))
print ("The Confusion matrix is: \n", cm)
print ("\n")
print ("The report is:\n", report)
# Out:
# The Confusion matrix is:
#  [[4313  670]
#  [ 369 2648]]
#
#
# The report is:
#                precision    recall  f1-score   support
#
#           no       0.92      0.87      0.89      4983
#          yes       0.80      0.88      0.84      3017
#
#     accuracy                           0.87      8000
#    macro avg       0.86      0.87      0.86      8000
# weighted avg       0.87      0.87      0.87      8000
